# %%
#https://seanprashad.com/leetcode-patterns/

# %%
"""
102. Binary Tree Level Order Traversal

Given a binary tree, return the level order traversal of its nodes' values. (ie, from left to right, level by level).

For example:
Given binary tree [3,9,20,null,null,15,7],
    3
   / \
  9  20
    /  \
   15   7
return its level order traversal as:
[
  [3],
  [9,20],
  [15,7]
]
"""
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def levelOrder(self, root: TreeNode) -> List[List[int]]:
        if not root: return root
        queue = [root]
        result = []
        
        
        def bfs(queue, result):
            if len(queue) == 0:
                return result
            levelValue =[]
            count = 0
            length = len(queue)
            while count < length:
                node = queue[0]
                queue = queue[1:]
                levelValue.append(node.val)
  
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
                    
                count += 1
            result.append(levelValue)
            #print(result)

            return bfs(queue, result)

        return bfs(queue, result)

# %%
"""
104. Maximum Depth of Binary Tree

Given the root of a binary tree, return its maximum depth.

A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.

Example 1:


Input: root = [3,9,20,null,null,15,7]
Output: 3
Example 2:

Input: root = [1,null,2]
Output: 2
Example 3:

Input: root = []
Output: 0

"""
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: TreeNode,currentDepth = 0) -> int:
        
        if not root: 
            return currentDepth
        currentDepth += 1
        #if root:
        #    print(root.val,currentDepth)
        return max(self.maxDepth(root.right,currentDepth),self.maxDepth(root.left,currentDepth))

# %%
"""
34. Find First and Last Position of Element in Sorted Array

Given an array of integers nums sorted in ascending order, find the starting and ending position of a given target value.

If target is not found in the array, return [-1, -1].

Follow up: Could you write an algorithm with O(log n) runtime complexity?

 

Example 1:

Input: nums = [5,7,7,8,8,10], target = 8
Output: [3,4]
Example 2:

Input: nums = [5,7,7,8,8,10], target = 6
Output: [-1,-1]

"""

class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
    
        
        def BS(nums,left,right,target):
            while left <= right:
                middle = (left+right)//2
                #print("Middle:",middle)
                
                if nums[middle] < target:
                    left = middle +1
                elif nums[middle] > target:
                    right = middle - 1
                else:
                    return middle
            return -1
        
        if not nums: return [-1,-1]
        
        valueFound = BS(nums,0,len(nums)-1,target)
        #print("valueFound",valueFound)
        
        if valueFound == -1: return [-1,-1]
        
        startPos = valueFound
        lastPos = valueFound
        
        #find start pos
        while startPos != -1:
            temp = startPos
            startPos = BS(nums,0,startPos-1,target)
            #print("Temp:",temp,"startPos:",startPos)
        startPos = temp
        
        #find end pos
        while lastPos != -1:
            temp = lastPos
            lastPos = BS(nums,lastPos+1,len(nums)-1,target)
            
        lastPos = temp
        
        return [startPos,lastPos]

# %%
"""
1249. Minimum Remove to Make Valid Parentheses

Given a string s of '(' , ')' and lowercase English characters. 

Your task is to remove the minimum number of parentheses ( '(' or ')', in any positions ) so that the resulting parentheses string is valid and return any valid string.

Formally, a parentheses string is valid if and only if:

It is the empty string, contains only lowercase characters, or
It can be written as AB (A concatenated with B), where A and B are valid strings, or
It can be written as (A), where A is a valid string.
 

Example 1:

Input: s = "lee(t(c)o)de)"
Output: "lee(t(c)o)de"
Explanation: "lee(t(co)de)" , "lee(t(c)ode)" would also be accepted.
Example 2:

Input: s = "a)b(c)d"
Output: "ab(c)d"
Example 3:

Input: s = "))(("
Output: ""
Explanation: An empty string is also valid.
Example 4:

Input: s = "(a(b(c)d)"
Output: "a(b(c)d)"
"""
class Solution:
    def minRemoveToMakeValid(self, s: str) -> str:
        #loop through string
        #init result str
        #if letter update res
        #if open ---> update closing and update in rest with index pos
        #if close --> pop. if equal continue. else remove bracket.
        
        if not s: return ""
        
        validParanthesis = {"(":")",
                           "{":"}",
                           "[":"]"}
        
        closeParanthesis = {")","}","]"}
        
        res = ""
        stack = []
        for l in s:
            if l in validParanthesis:
                #print("Open --",l)
                stack.append([validParanthesis[l],len(res)])
                res += l
                
            elif l in closeParanthesis:
                #print("Close --",l)
                if len(stack) == 0:
                    pass
                elif l == stack.pop()[0]:
                    res += l
                else:
                    pass
            else:
                res += l
        print(stack,res)
        
        
        if len(stack) > 0 and len(res)>0:
            finalRes = ""
            resIdx = 0 
            for item in stack:
                #print(resIdx,item[1])
                while item[1] != resIdx:
                    #print("adding final res:",res[resIdx])
                    finalRes += res[resIdx]
                    resIdx += 1
                resIdx += 1
            finalRes += res[resIdx:]
            return finalRes
                
                

        return res

# %%
"""
20. Valid Parentheses

Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.

An input string is valid if:

Open brackets must be closed by the same type of brackets.
Open brackets must be closed in the correct order.
 

Example 1:

Input: s = "()"
Output: true
Example 2:

Input: s = "()[]{}"
Output: true
Example 3:

Input: s = "(]"
Output: false
"""

class Solution:
    def isValid(self, s: str) -> bool:
        
        validParanthesis = {"(":")",
                           "{":"}",
                           "[":"]"}
        closeParanthesis = {")","}","]"}
        
        #loop through string
        #if open paranthesis update stack with closing p
        # if close paranthesis. pop stack. if equal continue. else return none
        
        stack = []
        for l in s:
            #print("Processing:",l)
            if l in validParanthesis:
                #print("open --",l)
                stack.append(validParanthesis[l])
            elif l in closeParanthesis:
                #print("close --",l)
                if not len(stack)>0: return 0
                if len(stack)>0 and l != stack.pop():
                    return 0

            else:
                return 0
        if len(stack) != 0:
            return 0
        return 1

# %%
"""
142. Linked List Cycle II

Given a linked list, return the node where the cycle begins. If there is no cycle, return null.

There is a cycle in a linked list if there is some node in the list that can be reached again by continuously following the next pointer. Internally, pos is used to denote the index of the node that tail's next pointer is connected to. Note that pos is not passed as a parameter.

Notice that you should not modify the linked list.

 

Example 1:


Input: head = [3,2,0,-4], pos = 1
Output: tail connects to node index 1
Explanation: There is a cycle in the linked list, where tail connects to the second node
"""
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def detectCycle(self, head: ListNode) -> ListNode:
        if not head: return head
        #detect cycle
        # if there is cycle
        # move fast ptr and head and return when equal
        
        slow = head
        fast = head

        while fast:
            slow = slow.next
            if fast.next and fast.next.next:
                fast = fast.next.next
            else:
                return None
                
            if fast == slow:
                #cycle detected
                #print("cycle detected --",fast.val)
                p1 = head
                p2 = fast
                while p1 != p2:
                    #print(p1.val,"---",p2.val)
                    p1 = p1.next
                    p2 = p2.next
                return p1
        
        return None

# %%
"""
430. Flatten a Multilevel Doubly Linked List
You are given a doubly linked list which in addition to the next and previous pointers, it could have a child pointer, which may or may not point to a separate doubly linked list. These child lists may have one or more children of their own, and so on, to produce a multilevel data structure, as shown in the example below.
Flatten the list so that all the nodes appear in a single-level, doubly linked list. You are given the head of the first level of the list.
Example 1:
Input: head = [1,2,3,4,5,6,null,null,null,7,8,9,10,null,null,11,12]
Output: [1,2,3,7,8,11,12,9,10,4,5,6]
"""

"""
# Definition for a Node.
class Node:
    def __init__(self, val, prev, next, child):
        self.val = val
        self.prev = prev
        self.next = next
        self.child = child
loop through nodes
if node has child
store tmpnext = current.next
map current --> child
looop through when current is none and has tmp next --- prev.next--> tmpnext


def flattenChild(current):
	tail = current.next
	current.next = current.child
	current.child = None
	while current:
		prevNode = current
		current = current.next
	prevNode.next = tail
	return current

"""

class Solution:
    def flatten(self, head: 'Node') -> 'Node':
        def flattenChild(current):
            tmp = current
            tail = current.next
            current.next = current.child
            current.child.prev = current
            current.child = None
            while current:
                prevNode = current
                current = current.next
            prevNode.next = tail
            if tail:
                tail.prev = prevNode
            return tmp
        
        if not head: return head
        currentNode = head
        while currentNode:
            prevNode = currentNode
            #print(currentNode.val)
            if currentNode.child:
                #print("has child")
                prevNode = flattenChild(currentNode)
            currentNode = prevNode.next
        return head

# %%
"""
92. Reverse Linked List II
Reverse a linked list from position m to n. Do it in one-pass.
Note: 1 ≤ m ≤ n ≤ length of list.
Example:
Input: 1->2->3->4->5->NULL, m = 2, n = 4
Output: 1->4->3->2->5->NULL
"""
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        #loop through ll having idx as memory
        #when idx is m--tail = m
        #when idx is n -- m-1.next = n
        #tail.next = n.next
        
        def revList(prevNode,currentNode,m,n,idx):
            prevTemp = prevNode
            tail = currentNode
            nTmp = n+1
            prevNode = None
            while idx < nTmp and currentNode:
                #print("reversing",currentNode.val,idx)
                tmp = currentNode.next
                currentNode.next = prevNode
                prevNode = currentNode
                currentNode=tmp
                idx += 1
            tail.next = currentNode   
            if prevTemp:
                prevTemp.next = prevNode
            else:
                return prevNode
            
            return None
                
        
        if not head.next: return head
        prevNode = None
        currentNode = head
        idx = 1
        while currentNode:
            #print(idx,currentNode.val)
            
            if idx == m:
                #print("calling rev list")
                head1 = revList(prevNode,currentNode,m,n,idx)
                if head1:
                    return head1
                return head

                
            prevNode= currentNode
            currentNode = currentNode.next
            idx += 1

# %%
"""
206. Reverse Linked List

Reverse a singly linked list.

Example:

Input: 1->2->3->4->5->NULL
Output: 5->4->3->2->1->NULL
"""
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        if not head: return None
        
        prevNode = None
        currentNode = head
        nextNode = head.next
                
        while currentNode:
            #print(currentNode.val)
            tmp = currentNode.next
            if currentNode.next and currentNode.next.next:
                nextNode = currentNode.next.next
            currentNode.next = prevNode
            prevNode = currentNode
            currentNode = tmp
        return prevNode
            

            
        return head

# %%
"""
680. Valid Palindrome II

Given a non-empty string s, you may delete at most one character. Judge whether you can make it a palindrome.

Example 1:
Input: "aba"
Output: True
Example 2:
Input: "abca"
Output: True
Explanation: You could delete the character 'c'.
"""
def isPalindrome(S):
  l = 0
  r = len(S)-1
  while l<=r:
    if S[l] != S[r]:
      return 0
    l += 1
    r -= 1
  return 1

def validPalindrome(s):
  """
  init l and r pointer
  move pointer inwords and check equal
  if not equal
  remove l or r to check palindrome
  else return false
  """
  l = 0
  r = len(s)-1
  if len(s) < 3: return 0
  while l<=r:
    print(l,r)
    if l == r:
      return 1
    if s[l] == s[r]:
      l += 1
      r -= 1
    else:
      print("l:",s[:l]+s[l+1:])
      print("r:",s[:r]+s[r+1:])
      if isPalindrome(s[:l]+s[l+1:]):
        return 1
      elif isPalindrome(s[:r]+s[r+1:]):
        return 1
      else:
        return 0
  return 1

s = "acaa"
validPalindrome(s)
# Out:
# 0 3
# 1 2
# l: aaa
# r: aca
# 1

# %%
s = "abcd"
s[:1]+s[2:]
# Out:
# 'acd'

# %%
def isPalindrome(S):
  l = 0
  r = len(S)-1
  while l<=r:
    if S[l] != S[r]:
      return 0
    l += 1
    r -= 1
  return 1

S = "babbab"
isPalindrome(S)
# Out:
# 1

# %%
"""
5. Longest Palindromic Substring
Given a string s, return the longest palindromic substring in s.

Example 1:

Input: s = "babad"
Output: "bab"
Note: "aba" is also a valid answer.
Example 2:

Input: s = "cbbd"
Output: "bb"
Example 3:

Input: s = "a"
Output: "a"
"""

def isPalindrome(S):
  l = 0
  r = len(S)-1
  while l<=r:
    if S[l] != S[r]:
      return 0
    l += 1
    r -= 1
  return 1

def longestPalindrome(s):
  res = ""
  l = r = 0
  while (r-l+1) <= len(s):
    print("slider:",s[l:r+1])
    print(l,r)
    if isPalindrome(s[l:r+1]):
      print("Yes it is palindrome")
      if len(res)<len(s[l:r+1]):
        print("updating res ")
        res = s[l:r+1]
      print("increasing the slider")
      r = len(s[l:r+1])
      if r >= len(s):
        print("out of index.increasing the slider.")
        r = len(res)
      l = 0

    else:     
      print("moving the slider")
      r += 1
      l += 1
      if r >= len(s):
        print("out of index.increasing the slider")
        print("length",len(s[l-1:r]))
        r = len(s[l-1:r])
        l = 0
  return res

s = "abbcccbbbcaaccbababcbcabca" #"babad" #"abadd" # 
longestPalindrome(s)
# Out:
# slider: a
# 0 0
# Yes it is palindrome
# updating res
# increasing the slider
# slider: ab
# 0 1
# moving the slider
# slider: bb
# 1 2
# Yes it is palindrome
# updating res
# increasing the slider
# slider: abb
# 0 2
# moving the slider
# slider: bbc
# 1 3
# moving the slider
# slider: bcc
# 2 4
# moving the slider
# slider: ccc
# 3 5
# Yes it is palindrome
# updating res
# increasing the slider
# slider: abbc
# 0 3
# moving the slider
# slider: bbcc
# 1 4
# moving the slider
# slider: bccc
# 2 5
# moving the slider
# slider: cccb
# 3 6
# moving the slider
# slider: ccbb
# 4 7
# moving the slider
# slider: cbbb
# 5 8
# moving the slider
# slider: bbbc
# 6 9
# moving the slider
# slider: bbca
# 7 10
# moving the slider
# slider: bcaa
# 8 11
# moving the slider
# slider: caac
# 9 12
# Yes it is palindrome
# updating res
# increasing the slider
# slider: abbcc
# 0 4
# moving the slider
# slider: bbccc
# 1 5
# moving the slider
# slider: bcccb
# 2 6
# Yes it is palindrome
# ...

# %%
"""
5. Longest Palindromic Substring
Given a string s, return the longest palindromic substring in s.

Example 1:

Input: s = "babad"
Output: "bab"
Note: "aba" is also a valid answer.
Example 2:

Input: s = "cbbd"
Output: "bb"
Example 3:

Input: s = "a"
Output: "a"
"""

def isPalindrome(S):
  l = 0
  r = len(S)-1
  while l<=r:
    if S[l] != S[r]:
      return 0
    l += 1
    r -= 1
  return 1

def longestPalindrome(s):
  res = ""
  l = 0
  r = len(s)-1
  slider = r
  while slider > 0:
    print("slider:",s[l:r+1])
    print(l,r)
    if isPalindrome(s[l:r+1]):
      print("Yes it is palindrome")
      return s[l:r+1]

    if r < len(s):
      print("moving the slider")
      l += 1
      r += 1

    else:     
      print("Decreasing the slider")
      slider -= 1
      l = 0
      r = l + slider
  return None

#s = "ab"#"abadd" #"abbcccbbbcaaccbababcbcabca" # "babad" #
s = "..."
longestPalindrome(s)

# %%
a = "abcd"
a[::-1]
# Out:
# 'dcba'

# %%
"""
"""
def lengthOfLongestSubstring(s):
        
        """
        init left pointer as 0 and right pointer as 0
        move right pointer
        if R not in memory. inc longSub and add in memory
        if R in memory. move left ponter and calculate longsub and if longer update
        """

        leftP = 0
        rightP = 0
        memory = {}
        res = 0
        while rightP < len(s):
            print("leftP:",leftP,"Memory:",memory)
            print(s[leftP:rightP+1])
            if s[rightP] not in memory:
                print(s[rightP],"not in memory")
                memory[s[rightP]] = rightP

            elif (s[rightP] in memory):
                print(s[rightP],"in memory")
                if (memory[s[rightP]] >= leftP ):
                  print("within limit.moving left pointer and updating memory")
                  leftP = memory[s[rightP]] + 1
                  memory[s[rightP]] = rightP
                else:
                  print("updating memory index")
                  memory[s[rightP]] = rightP
            print("moving right pointer")
            rightP += 1
                
            if res < (rightP - leftP):
                res = rightP - leftP
                print("updating longest substring",res)

        return res

#s = "abcabcbb"
#s = "abba"
#s = "dvdf"
s = "aabaab!bb"
lengthOfLongestSubstring(s)
# Out:
# leftP: 0 Memory: {}
# a
# a not in memory
# moving right pointer
# updating longest substring 1
# leftP: 0 Memory: {'a': 0}
# aa
# a in memory
# within limit.moving left pointer and updating memory
# moving right pointer
# leftP: 1 Memory: {'a': 1}
# ab
# b not in memory
# moving right pointer
# updating longest substring 2
# leftP: 1 Memory: {'a': 1, 'b': 2}
# aba
# a in memory
# within limit.moving left pointer and updating memory
# moving right pointer
# leftP: 2 Memory: {'a': 3, 'b': 2}
# baa
# a in memory
# within limit.moving left pointer and updating memory
# moving right pointer
# leftP: 4 Memory: {'a': 4, 'b': 2}
# ab
# b in memory
# updating memory index
# moving right pointer
# leftP: 4 Memory: {'a': 4, 'b': 5}
# ab!
# ! not in memory
# moving right pointer
# updating longest substring 3
# leftP: 4 Memory: {'a': 4, 'b': 5, '!': 6}
# ab!b
# b in memory
# within limit.moving left pointer and updating memory
# moving right pointer
# leftP: 6 Memory: {'a': 4, 'b': 7, '!': 6}
# ...

# %%
a = {1:1,2:1}
del a[1]
a
# Out:
# {2: 1}

# %%
"""
Backspace String Compare

Given two strings S and T, return if they are equal when both are typed into empty text editors. # means a backspace character.

Note that after backspacing an empty text, the text will continue empty.

Example 1:

Input: S = "ab#c", T = "ad#c"
Output: true
Explanation: Both S and T become "ac".
Example 2:

Input: S = "ab##", T = "c#d#"
Output: true
Explanation: Both S and T become "".
Example 3:

Input: S = "a##c", T = "#a#c"
Output: true
Explanation: Both S and T become "c".
"""
class Solution:
    def backspaceCompare(self, S: str, T: str) -> bool:
        sRes = ""
        tRes = ""
        for letter in S:
            if letter == "#":
                sRes = sRes[:-1]
            else:
                sRes += letter
        for letter in T:
            if letter == "#":
                tRes = tRes[:-1]
            else:
                tRes += letter
        #print(sRes,tRes)
        if tRes == sRes: 
            return True
        else:
            return False

# %%
def backspaceCompare(S: str, T: str) -> bool:
        p1 = len(S)-1
        p2 = len(T)-1
        
        sHash = tHash = 0
        
        while p1>=0 or p2 >=0:
            if p1>= 0:
              sVal = S[p1]
            else:
              sVal = None
            if p2 >=0 : 
                tVal = T[p2]
            else:
              tVal = None
            
            print(sVal,tVal,"Pointer:",p1,p2)
            
            if (sHash == tHash == 0):
                print("Hash are zero")
                if (sVal == tVal != "#"):
                    print("moving pointer p1,p2")
                    p1 -= 1
                    p2 -= 1

                elif sVal != "#" and tVal != "#":
                    print("STring are not equal")
                    return False
            if sVal == "#":
                print("p1 is # and moving pointer")
                sHash += 1
                p1 -= 1
            if tVal == "#":
                print("p2 is # and moving pointer")
                tHash += 1
                p2 -= 1
            if sVal != "#" and sHash>0:
                print("p1 is not hash. moving pointer and deleting",sVal)
                p1 -= 1
                sHash -= 1
            if tVal != "#" and tHash>0:
                print("p2 is not hash. moving pointer and deleting",tVal)
                p2 -= 1
                tHash -= 1
        return True

S = "ab#cc#"
T = "ad#c"
backspaceCompare(S,T)
# Out:
# # c Pointer: 5 3
# Hash are zero
# p1 is # and moving pointer
# c c Pointer: 4 3
# p1 is not hash. moving pointer and deleting c
# c c Pointer: 3 3
# Hash are zero
# moving pointer p1,p2
# # # Pointer: 2 2
# Hash are zero
# p1 is # and moving pointer
# p2 is # and moving pointer
# b d Pointer: 1 1
# p1 is not hash. moving pointer and deleting b
# p2 is not hash. moving pointer and deleting d
# a a Pointer: 0 0
# Hash are zero
# moving pointer p1,p2
# True

# %%
a = 3
b = 4
a != b != 3
# Out:
# True

# %%
"""
42. Trapping Rain Water

Given n non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it can trap after raining.
Example 1:
Input: height = [0,1,0,2,1,0,1,3,2,1,2,1]
Output: 6
Explanation: The above elevation map (black section) is represented by array [0,1,0,2,1,0,1,3,2,1,2,1]. 
In this case, 6 units of rain water (blue section) are being trapped.
Example 2:
Input: height = [4,2,0,3,2,5]
Output: 9
"""

def trap(height):
  res = 0
  for idx,val in enumerate(height):
    maxLeft = max(height[:idx+1])
    maxRight = max(height[idx:])
    print("Val:",val,"Left:",maxLeft,"Right:",maxRight)
    current = min(maxLeft,maxRight)- val
    res += current
  return res


height = [4]
trap(height)
# Out:
# Val: 4 Left: 4 Right: 4
# 0

# %%
def trap(height) -> int:
  if not height: return 0
  maxLeft = height[0]
  maxRight = height[len(height)-1]
  leftP = 0
  rightP = len(height)-1
  totalWater = 0
    
  def calWater(minHeight,currentHeight):
          return minHeight-currentHeight
  count = -1
  while leftP < rightP:
    count +=1
    print("Step:",count)
            
    print(leftP,"<", rightP,"--",maxLeft,"--",maxRight)
                  
    if maxLeft<=maxRight:

        #move left pointer
        if height[leftP] >= maxLeft:
            maxLeft = height[leftP]
            print("updated maxLeft:",maxLeft)

        #update water
        else: # height[leftP]<maxLeft:
            totalWater += calWater(maxLeft,height[leftP])
            print("updated water:",calWater(maxLeft,height[leftP]))

    else: #maxLeft>maxRight:
      
      #move right pointer
      if height[rightP] > maxRight:
          maxRight = height[rightP]
          print("updated maxRight:",maxRight)

      #update water
      else: # height[rightP]<maxRight:
          totalWater += calWater(maxRight,height[rightP])
          print("updated water:",calWater(maxLeft,height[leftP]))

    if maxLeft <= maxRight:
        print("moving left pointer")
        leftP += 1
    else:
      print("moving right pointer")
      rightP -= 1

          
                
  return totalWater

height = [5,5,1,7,1,1,5,2,7,6]

trap(height)
# Out:
# Step: 0
# 0 < 9 -- 5 -- 6
# updated maxLeft: 5
# moving left pointer
# Step: 1
# 1 < 9 -- 5 -- 6
# updated maxLeft: 5
# moving left pointer
# Step: 2
# 2 < 9 -- 5 -- 6
# updated water: 4
# moving left pointer
# Step: 3
# 3 < 9 -- 5 -- 6
# updated maxLeft: 7
# moving right pointer
# Step: 4
# 3 < 8 -- 7 -- 6
# updated maxRight: 7
# moving left pointer
# Step: 5
# 4 < 8 -- 7 -- 7
# updated water: 6
# moving left pointer
# Step: 6
# 5 < 8 -- 7 -- 7
# updated water: 6
# moving left pointer
# Step: 7
# 6 < 8 -- 7 -- 7
# updated water: 2
# moving left pointer
# Step: 8
# 7 < 8 -- 7 -- 7
# updated water: 5
# moving left pointer
# 23

# %%
"""
1. Identify the pointer with the lesser value
2. Is this pointer value lesser than or equal to max on that side
  yes -> update max on that side
  no -> get water for pointer, add to total
3. move pointer inwards
4. repeat for other pointer
"""
def trap(height):
  leftP = 0
  rightP = len(height)-1
  maxLeft = 0
  maxRight = 0 
  res = 0
  while leftP < rightP:
    print("Pointers",height[leftP],height[rightP])
    if height[leftP] <= height[rightP]:
      if height[leftP] > maxLeft:
        maxLeft = height[leftP]
        print("Updating MaxLeft:",maxLeft)
      else:
        res += maxLeft-height[leftP]
        print("Total water:",res)
      leftP +=1
    else:
      if height[rightP] > maxRight:
        maxRight = height[rightP]
        print("Updating MaxRight:",maxRight)
      else:
        res += maxRight - height[rightP]
        print("Total water:",res)
      rightP -= 1
  return res



height = [0,1,0,2,1,0,1,3,2,1,2,1]
trap(height)
# Out:
# Pointers 0 1
# Total water: 0
# Pointers 1 1
# Updating MaxLeft: 1
# Pointers 0 1
# Total water: 1
# Pointers 2 1
# Updating MaxRight: 1
# Pointers 2 2
# Updating MaxLeft: 2
# Pointers 1 2
# Total water: 2
# Pointers 0 2
# Total water: 4
# Pointers 1 2
# Total water: 5
# Pointers 3 2
# Updating MaxRight: 2
# Pointers 3 1
# Total water: 6
# Pointers 3 2
# Total water: 6
# 6

# %%
"""
11. Container With Most Water

Given n non-negative integers a1, a2, ..., an , where each represents a point at coordinate (i, ai). 
n vertical lines are drawn such that the two endpoints of the line i is at (i, ai) and (i, 0). 
Find two lines, which, together with the x-axis forms a container, such that the container contains the most water.

Notice that you may not slant the container.

Example 1:
Input: height = [1,8,6,2,5,4,8,3,7]
Output: 49
Explanation: The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.
Example 2:

Input: height = [1,1]
Output: 1
Example 3:

Input: height = [4,3,2,1,4]
Output: 16
"""
def maxArea(height):
  res = 0
  leftPointer = 0
  rightPointer = len(height)-1
  while leftPointer < rightPointer:
    print(leftPointer, rightPointer)
    area = min(height[leftPointer],height[rightPointer]) * (rightPointer - leftPointer)
    if res < area:
      res = area
    if height[leftPointer] < height[rightPointer]:
      leftPointer += 1
    else:
      rightPointer -= 1
  
  return res

height = [4,3,2,1,4]
maxArea(height)
# Out:
# 0 4
# 0 3
# 0 2
# 0 1
# 16

# %%
"""
Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.

You may assume that each input would have exactly one solution, and you may not use the same element twice.

You can return the answer in any order.

 

Example 1:

Input: nums = [2,7,11,15], target = 9
Output: [0,1]
Output: Because nums[0] + nums[1] == 9, we return [0, 1].
Example 2:

Input: nums = [3,2,4], target = 6
Output: [1,2]
"""

def returnIndex(nums,target):

  memory = {}
  for idx,num in enumerate(nums):
    diff = target - num
    if diff not in memory:
      memory[num] = idx
    else:
      return [memory[diff],idx]


nums = [11,15,2,7]
target = 9
returnIndex(nums,target)
# Out:
# [2, 3]

# %%
memory ={11: 0, 15: 1, 2: 2}
memory[15]
# Out:
# 1

# %%
def maxSubarray(nums):
  if not nums: return None
  maxSum = [nums[0]]
  res = nums[0]
  for idx in range(1,len(nums)):
    sum = max(nums[idx], maxSum[-1]+nums[idx])
    maxSum.append(sum)
    res = max(res,sum)
  return res




nums = [-2,1,-3,4,-1,2,1,-5,4]
maxSubarray(nums)
# Out:
# 6

# %%
d = dict()
for x in enumerate(range(2)):
  d[x[0]] = x[1]
  d[x[1]+7] = x[0]
  print(d)
d
# Out:
# {0: 0, 7: 0}
# {0: 0, 7: 0, 1: 1, 8: 1}
# {0: 0, 1: 1, 7: 0, 8: 1}

# %%
"""
53. Maximum Subarray

Given an integer array nums, find the contiguous subarray (containing at least one number) which has the largest sum and return its sum.

Follow up: If you have figured out the O(n) solution, try coding another solution using the divide and conquer approach, which is more subtle.

 

Example 1:

Input: nums = [-2,1,-3,4,-1,2,1,-5,4]
Output: 6
Explanation: [4,-1,2,1] has the largest sum = 6.
Example 2:

Input: nums = [1]
Output: 1
Example 3:

Input: nums = [0]
Output: 0
"""

def maxSubarray(nums):
  if not nums: return nums
  sumnum=[nums[0]]
  res = nums[0]
  for idx in range(1,len(nums)):
    maxsum = max(nums[idx],sumnum[-1]+nums[idx])
    sumnum.append(maxsum)
    res = max(res,maxsum)
  return res

nums = [-2]
maxSubarray(nums)
# Out:
# -2

# %%
"""
121. Best Time to Buy and Sell Stock

Say you have an array for which the ith element is the price of a given stock on day i.

If you were only permitted to complete at most one transaction (i.e., buy one and sell one share of the stock), design an algorithm to find the maximum profit.

Note that you cannot sell a stock before you buy one.

Example 1:

Input: [7,1,5,3,6,4]
Output: 5
Explanation: Buy on day 2 (price = 1) and sell on day 5 (price = 6), profit = 6-1 = 5.
             Not 7-1 = 6, as selling price needs to be larger than buying price.
Example 2:

Input: [7,6,4,3,1]
Output: 0
Explanation: In this case, no transaction is done, i.e. max profit = 0.
"""
def calculateProfit(stocks):
  if not stocks: return 0
  
  minPrice = stocks[0]
  profit = 0

  for stock in stocks:
    minPrice = min(stock,minPrice)
    profit = max(profit,stock-minPrice)
  return profit


stocks = [1,4,2,3,10,4]
calculateProfit(stocks)
# Out:
# 9

# %%
for i in range(1, 4):
  print(i)
# Out:
# 1
# 2
# 3

# %%
"""
198. House Robber

You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed, the only constraint stopping you from robbing each of them is that adjacent houses have security system connected and it will automatically contact the police if two adjacent houses were broken into on the same night.

Given a list of non-negative integers representing the amount of money of each house, determine the maximum amount of money you can rob tonight without alerting the police.

Example 1:

Input: nums = [1,2,3,1]
Output: 4
Explanation: Rob house 1 (money = 1) and then rob house 3 (money = 3).
             Total amount you can rob = 1 + 3 = 4.
Example 2:

Input: nums = [2,7,9,3,1]
Output: 12
Explanation: Rob house 1 (money = 2), rob house 3 (money = 9) and rob house 5 (money = 1).
             Total amount you can rob = 2 + 9 + 1 = 12.
"""
def maxrob(loot):
  if not loot: return 0
  if len(loot)<3: return max(loot)
  memory = [loot[0],max(loot[0],loot[1])]

  for house in range(2,len(loot)):

    current = max(memory[-1],memory[-2]+loot[house])
    memory.append(current)
  print(memory)
  return memory.pop()


loot = []
maxrob(loot)
# Out:
# []

# %%
"""
70. Climbing Stairs
You are climbing a stair case. It takes n steps to reach to the top.

Each time you can either climb 1 or 2 steps. In how many distinct ways can you climb to the top?

Example 1:

Input: 2
Output: 2
Explanation: There are two ways to climb to the top.
1. 1 step + 1 step
2. 2 steps
Example 2:

Input: 3
Output: 3
Explanation: There are three ways to climb to the top.
1. 1 step + 1 step + 1 step
2. 1 step + 2 steps
3. 2 steps + 1 step
"""
def steps(totalSteps):
  if totalSteps<4: return totalSteps
  memory = {}
  for k,v in enumerate(range(0,4)):
    memory[k]=v
  for step in range(4,totalSteps+1):
    memory[step] = memory[step-1]+memory[step-2]
  return memory[totalSteps]

totalSteps = 5
steps(totalSteps)
# Out:
# 8

# %%
"""
136. Single Number
Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.

Follow up: Could you implement a solution with a linear runtime complexity and without using extra memory?

 

Example 1:

Input: nums = [2,2,1]
Output: 1
Example 2:

Input: nums = [4,1,2,1,2]
Output: 4
Example 3:

Input: nums = [1]
Output: 1
"""
def singleNum(nums):
  setNums = sum(set(nums))*2
  nums = sum(nums)
  return setNums-nums

nums = [1]
singleNum(nums)
# Out:
# 1

# %%
2^1
# Out:
# 3

# %%
"""
448. Find All Numbers Disappeared in an Array

Given an array of integers where 1 ≤ a[i] ≤ n (n = size of array), some elements appear twice and others appear once.

Find all the elements of [1, n] inclusive that do not appear in this array.

Could you do it without extra space and in O(n) runtime? You may assume the returned list does not count as extra space.

Example:

Input:
[4,3,2,7,8,2,3,1]

Output:
[5,6]
"""
def missingNum(nums):
  numset = set(nums)
  res = set(range(1,len(nums)+1)) - numset

  return list(res)


nums = [1,1]
missingNum(nums)
# Out:
# [2]

# %%
set(nums)
# Out:
# {1, 2, 3, 4, 7, 8}

# %%
sum(set(nums))
# Out:
# 25

# %%
"""
268. Missing Number

Given an array nums containing n distinct numbers in the range [0, n], return the only number in the range that is missing from the array.

Follow up: Could you implement a solution using only O(1) extra space complexity and O(n) runtime complexity?

 

Example 1:

Input: nums = [3,0,1]
Output: 2
Explanation: n = 3 since there are 3 numbers, so all numbers are in the range [0,3]. 2 is the missing number in the range since it does not appear in nums.
Example 2:

Input: nums = [0,1]
Output: 2
Explanation: n = 2 since there are 2 numbers, so all numbers are in the range [0,2]. 2 is the missing number in the range since it does not appear in nums.
"""

def missingNum(nums):
  orgNums = range(0,len(nums)+1)
  res = sum(orgNums)-sum(nums)
  return res


nums = [0,1]
missingNum(nums)
# Out:
# 2

# %%
"""
217. Contains Duplicate

Given an array of integers, find if the array contains any duplicates.

Your function should return true if any value appears at least twice in the array, and it should return false if every element is distinct.

Example 1:

Input: [1,2,3,1]
Output: true
Example 2:

Input: [1,2,3,4]
Output: false
Example 3:

Input: [1,1,1,3,3,4,3,2,4,2]
Output: true
"""
def containsDuplicate(nums):
  memory = {}
  for num in nums:
    if num not in memory:
      memory[num] = True
    else:
      return True 
  return False
nums = [1,2,3,4]
containsDuplicate(nums)
# Out:
# False

# %%
"""
852. Peak Index in a Mountain Array

Let's call an array arr a mountain if the following properties hold:

arr.length >= 3
There exists some i with 0 < i < arr.length - 1 such that:
arr[0] < arr[1] < ... arr[i-1] < arr[i]
arr[i] > arr[i+1] > ... > arr[arr.length - 1]
Given an integer array arr that is guaranteed to be a mountain, return any i such that arr[0] < arr[1] < ... arr[i - 1] < arr[i] > arr[i + 1] > ... > arr[arr.length - 1].

 

Example 1:

Input: arr = [0,1,0]
Output: 1
Example 2:

Input: arr = [0,2,1,0]
Output: 1
Example 3:

Input: arr = [0,10,5,2]
Output: 1
Example 4:

Input: arr = [3,4,5,1]
Output: 2
Example 5:

Input: arr = [24,69,100,99,79,78,67,36,26,19]
Output: 2
 

Constraints:

3 <= arr.length <= 104
0 <= arr[i] <= 106
arr is guaranteed to be a mountain array.
"""

def peakIndexInMountainArray(self, arr: List[int]) -> int:
    if len(arr)<3:
        return None
    for i in range(1,len(arr)):
        if arr[i-1]<arr[i] and arr[i]>arr[i+1]:
            return i
    return None

# %%
def nextGreatestLetter(letters, target):
  #if letters[0]<target: return letters[0]
  if target >= letters[-1]:
    return letters[-1]
  start= 0
  end = len(letters)
  while start<end:
    mid = (end+start)//2
    print(start,end)
    if letters[mid] <= target: 
      start = mid+1
      print("right:",letters[start:end])
    else:
      end = mid
      print("left:",letters[start:end])
  print(letters[end])



letters = ["c", "f", "j","k","m"]
target = "m"
nextGreatestLetter(letters, target)
# Out:
# 'm'

# %%
1//2
# Out:
# 0

# %%
"""
744. Find Smallest Letter Greater Than Target
Given a list of sorted characters letters containing only lowercase letters, and given a target letter target, find the smallest element in the list that is larger than the given target.

Letters also wrap around. For example, if the target is target = 'z' and letters = ['a', 'b'], the answer is 'a'.

Examples:
Input:
letters = ["c", "f", "j"]
target = "a"
Output: "c"

Input:
letters = ["c", "f", "j"]
target = "c"
Output: "f"

Input:
letters = ["c", "f", "j"]
target = "d"
Output: "f"

Input:
letters = ["c", "f", "j"]
target = "g"
Output: "j"
"""

class Solution:
    def nextGreatestLetter(self, letters: List[str], target: str) -> str:
        target = ord(target)
        if letters is None: return None
        if target >= ord(letters[-1]):
            return letters[0]
        
        startIndex = 0 
        endIndex = len(letters)
        
        while startIndex<endIndex:
            midIndex = (startIndex+endIndex)//2
            
            if ord(letters[midIndex]) <=target:
                startIndex = midIndex+1
            else:
                endIndex = midIndex
        return letters[startIndex%len(letters)]

# %%
"""
21. Merge Two Sorted Lists
Merge two sorted linked lists and return it as a new sorted list. The new list should be made by splicing together the nodes of the first two lists.
Example 1:
Input: l1 = [1,2,4], l2 = [1,3,4]
Output: [1,1,2,3,4,4]
"""

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        #print(l1.val,l2.val)
        if l1 is None:
            return l2
        if l2 is None:
            return l1
        if l1.val <= l2.val:
            #print("l1",l1.val)
            l1.next = self.mergeTwoLists(l1.next,l2)
            return l1
        else:
            #print("l2",l2.val)
            l2.next = self.mergeTwoLists(l1,l2.next)
            return l2

# %%
# Reverse linked list
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        if head is None: return head
        
        tail = head
        current = head
        nextNode = head.next
        
        while nextNode:
            temp = nextNode.next
            nextNode.next = current
            current =nextNode 
            nextNode = temp
        tail.next = None
        
        return current

# %%
"""
83. Remove Duplicates from Sorted List

Given a sorted linked list, delete all duplicates such that each element appear only once.

Example 1:

Input: 1->1->2
Output: 1->2
Example 2:

Input: 1->1->2->3->3
Output: 1->2->3
"""

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def deleteDuplicates(self, head: ListNode) -> ListNode:
        if head is None: return None
        dummyHead = ListNode("a")
        dummyHead.next = head
        
        def removeNode(prev,node):
            if node:
                if prev.val == node.val:
                    prev.next = node.next
                    removeNode(prev,node.next)
                else:
                    removeNode(node,node.next)
            else:
                return None
        removeNode(dummyHead,head)
        return dummyHead.next

# %%
"""
203. Remove Linked List Elements
Easy

2049

99

Add to List

Share
Remove all elements from a linked list of integers that have value val.

Example:

Input:  1->2->6->3->4->5->6, val = 6
Output: 1->2->3->4->5
"""
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeElements(self, head: ListNode, val: int) -> ListNode:
        if head is None: return None
        
        dummyHead = ListNode(-1)
        dummyHead.next = head
        
        def removeNode(prev,node):
            if node:
                if node.val == val:
                    prev.next = node.next
                    removeNode(prev,node.next)
                else:
                    removeNode(node,node.next)
            else:
                return 
            
        removeNode(dummyHead,head)
        return dummyHead.next

# %%
class node:
  def __init__(self,value):
    self.value = value
    self.next = None

class linkedlist:
  def __init__(self):
    self.head = None
    self.tail = self.head
    self.length = 0
  
  def append(self,value):
    current = node(value)
    if self.head is None:
      self.head = current
      self.tail = self.head
      self.length = 1
    else:
      self.tail.next = current
      self.tail = self.tail.next
      self.length += 1

  def prepend(self,val):
    current = node(val)
    if self.head is None:
      self.head = current
      self.tail = self.head
      self.length = 1
      return
    temp = self.head
    self.head = current
    self.head.next = temp
    self.length += 1
  
  def insert(self,pos,val):
    if pos == 1: 
      self.prepend(val)
      return
    if pos > self.length:
      print("Out of range. Appending at last")
      self.append(val)
      return
    count = 1
    newNode = node(val)
    current = self.head
    while count != pos:
      previous = current
      current = current.next
      count += 1
    print("inserting between {} - {}".format(previous.value,current.value))
    previous.next = newNode
    newNode.next = current
    self.length += 1
    print("Length:",self.length)

  def reverse(self):
    self.tail = self.head
    current = self.head
    nextNode = current.next
    while nextNode:
      temp = nextNode.next
      nextNode.next = current
      current = nextNode
      nextNode = temp
    self.head = current
    self.tail.next = None

  def display(self):
    current = self.head
    while current:
      print(current.value,end =" ")
      current = current.next
    print("\n")


ll = linkedlist()
ll.append(1)
ll.append(2)
ll.append(3)
ll.prepend(0)
#ll.insert(3,100)
ll.display()
ll.reverse()
ll.display()
# Out:
# 0 1 2 3
#
# 3 2 1 0

# %%
 
#Find the largest word in a given string
#Examples
#Input: "fun&!! time"
#Output: time
def largestWord(word):
  if word is None: return None
  word = word + " "
  res = []
  tempWord = ""
  largestWord = -1
  for letter in word:
    if letter.isalnum():
      tempWord += letter

    elif letter == " ":
      res.append(tempWord)
      if len(tempWord)>largestWord: 
        largestWord = len(res)-1
        print("largest word",largestWord)
      print(res,largestWord)
      tempWord = ""
  return res[largestWord]


word = "fun&!! time all@2111 to "
largestWord(word)
# Out:
# largest word 0
# ['fun'] 0
# largest word 1
# ['fun', 'time'] 1
# largest word 2
# ['fun', 'time', 'all2111'] 2
# ['fun', 'time', 'all2111', 'to'] 2
# ['fun', 'time', 'all2111', 'to', ''] 2
# 'all2111'

# %%
a = "1" + " "
len(a)
# Out:
# 2

# %%
[5,6,4]+[0,0]
# Out:
# [5, 6, 4, 0, 0]

# %%
#Given an array nums, write a function to move all 0's to the end of it while maintaining the relative order of the non-zero elements.
#Example:
#Input: [0,1,0,3,12]
#Output: [1,3,12,0,0]

def moveZero(array):
  array.sort(key = bool,reverse=True)
  #print(array)
  return array

array = [0,1,0,3,12]
moveZero(array)
# Out:
# [1, 3, 12, 0, 0]

# %%
#Google Question
#Given an array, return the first recurring character
#Example1 : array = [2,1,4,2,6,5,1,4]
#It should return 2
#Example 2 : array = [2,6,4,6,1,3,8,1,2]
#It should return 6

def recurringChar(array):
  table = {}
  for val in array:
    if val not in table:
      table[val] = True
    else:
      return val
    print(table)


array = [2,6,4,6,1,3,8,1,2]
recurringChar(array)
# Out:
# {2: True}
# {2: True, 6: True}
# {2: True, 6: True, 4: True}
# 6

# %%
#Given a string and a pattern, write a program to find all occurences of the pattern in the string
#For example, string = "THIS IS A TEST TEXT", pattern = "TEST"
#Output = Pattern found at index 10
#Example 2, string =  "AABAACAADAABAABA", pattern =  "AABA"
#Output: Pattern found at index 0, Pattern found at index 9, Pattern found at index 12

def findOccurance(string, pattern):
  patternLength = len(pattern)
  stringLength = len(string)
  index = 0
  span = stringLength - patternLength
  while(index <= span):
    print(string[index:index+patternLength],pattern,patternLength,index)
    if string[index:index+patternLength] == pattern:
      print("Occured: ",index)
    index += 1

string =  "AABAACAADAABAABA"
pattern =  "AABA"
findOccurance(string, pattern)
# Out:
# AABA AABA 4 0
# Occured:  0
# ABAA AABA 4 1
# BAAC AABA 4 2
# AACA AABA 4 3
# ACAA AABA 4 4
# CAAD AABA 4 5
# AADA AABA 4 6
# ADAA AABA 4 7
# DAAB AABA 4 8
# AABA AABA 4 9
# Occured:  9
# ABAA AABA 4 10
# BAAB AABA 4 11
# AABA AABA 4 12
# Occured:  12

# %%
"""
234. Palindrome Linked List

Given a singly linked list, determine if it is a palindrome.

Example 1:

Input: 1->2 -> 1
Output: false
Example 2:

Input: 1->2->2->1
Output: true

"""

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next

class Solution:
    def isPalindrome(self, head: ListNode) -> bool:
        actual = []
        current = head
        while current:
            actual.append(current.val)
            current = current.next
        for first, last in zip(actual,actual[::-1]):
            if first != last: return False
        return True



# two pointer

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next

# 1 3 4 5 4 3 1
# 1 4 4 1
# 1 3 4 5
class Solution:
    def isPalindrome(self, head: ListNode) -> bool:
        if not head: return True
        
        slow = head
        fast = head
        half_list = []
        even = False

        while slow:
            half_list.append(slow.val)
                
            if fast.next and fast.next.next:
                
                fast = fast.next.next
                slow = slow.next
                
            else:
                if fast.next: even = True
                break
        
        if not even:
            half_list.pop()

        slow = slow.next
        while slow:
            if slow.val != half_list.pop():
                return False
            slow = slow.next
        return True

# %%
"""
876. Middle of the Linked List
Given a non-empty, singly linked list with head node head, return a middle node of linked list.

If there are two middle nodes, return the second middle node.

 

Example 1:

Input: [1,2,3,4,5]
Output: Node 3 from this list (Serialization: [3,4,5])
The returned node has value 3.  (The judge's serialization of this node is [3,4,5]).
Note that we returned a ListNode object ans, such that:
ans.val = 3, ans.next.val = 4, ans.next.next.val = 5, and ans.next.next.next = NULL.
Example 2:

Input: [1,2,3,4,5,6]
Output: Node 4 from this list (Serialization: [4,5,6])
Since the list has two middle nodes with values 3 and 4, we return the second one.

"""


# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def middleNode(self, head: ListNode) -> ListNode:
            current = head
            fast_pointer = head
            while current:
                try:  
                    fast_pointer = fast_pointer.next.next
                except:
                    return current
                current = current.next

# %%
"""
141. Linked List Cycle

Given head, the head of a linked list, determine if the linked list has a cycle in it.

There is a cycle in a linked list if there is some node in the list that can be reached again by continuously following the next pointer. Internally, pos is used to denote the index of the node that tail's next pointer is connected to. Note that pos is not passed as a parameter.

Return true if there is a cycle in the linked list. Otherwise, return false.

Follow up:

Can you solve it using O(1) (i.e. constant) memory?

 

Example 1:


Input: head = [3,2,0,-4], pos = 1
Output: true
Explanation: There is a cycle in the linked list, where the tail connects to the 1st node (0-indexed).
"""


# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def hasCycle(self, head: ListNode) -> bool:
        if head is None: return False
        
        slow_pointer = head
        fast_pointer = head
        
        while slow_pointer:
            #print(slow_pointer.val)
            
            try:
                slow_pointer = slow_pointer.next
                fast_pointer = fast_pointer.next.next
            except:
                return False
            if slow_pointer == fast_pointer:
                return True
        return False

# %%
"""
Given an integer array nums, find the sum of the elements between indices i and j (i ≤ j), inclusive.

Example:

Given nums = [-2, 0, 3, -5, 2, -1]

sumRange(0, 2) -> 1
sumRange(2, 5) -> -1
sumRange(0, 5) -> -3
"""

class NumArray:

    def __init__(self, nums: List[int]):
        self.nums = nums
        

    def sumRange(self, i: int, j: int) -> int:
        length = len(self.nums)
        if 0 <= i < length:
            
            if 0 <= j < length:
                return(sum(self.nums[i:j+1]))
        


# Your NumArray object will be instantiated and called as such:
# obj = NumArray(nums)
# param_1 = obj.sumRange(i,j)

# %%
"""
53. Maximum Subarray

Given an integer array nums, find the contiguous subarray (containing at least one number) which has the largest sum and return its sum.
Follow up: If you have figured out the O(n) solution, try coding another solution using the divide and conquer approach, which is more subtle.

Example 1:
Input: nums = [-2,1,-3,4,-1,2,1,-5,4]
Output: 6
Explanation: [4,-1,2,1] has the largest sum = 6.

Example 2:
Input: nums = [1]
Output: 1

Example 3:
Input: nums = [0]
Output: 0

Example 4:
Input: nums = [-1]
Output: -1

Example 5:
Input: nums = [-2147483647]
Output: -2147483647

"""

# bottom up approach
# for each val --> update min, max and sum
def maxSubArray(nums):
          if len(nums) == 1: return nums[0]
          sum = [nums[0]]
          res = nums[0]

          for curr_val in nums[1:]:
            max_sum = max(curr_val,curr_val+sum[-1])
            sum.append(max_sum)
            #-1 < -2 --- yes
            if res < max_sum :
               #print(res,"less than",max_sum) 
               res = max_sum

          #print(sum,res)
          return res
   


#sum = [-2,1,-2,2,5,7,8]
# max(-2) = -2
# max(1,-2+1)= 1
# max(curr,sum+-3) = max(-3,1-3) = -2
# max(4,-2+4) = 4
# max(-1,4-1) = 3 
# max(2,3+2) = 5
# max(1,5+1) = 6
# max(-5,-5+6) = 1
# max(4,4+1) = 5
nums = [-2,1,-3,4,-1,2,1,-5,4]
maxSubArray(nums)
# Out:
# [-2, -2, 1, -2, 4, 3, 5, 6, 1, 5]
# 6

# %%
sum = []
sum[-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-efe38b6134f7> in <module>()
#       1 sum = []
# ----> 2 sum[-1]
#
# IndexError: list index out of range

# %%
"""
121. Best Time to Buy and Sell Stock

Say you have an array for which the ith element is the price of a given stock on day i.

If you were only permitted to complete at most one transaction (i.e., 
buy one and sell one share of the stock), design an algorithm to find the maximum profit.

Note that you cannot sell a stock before you buy one.

Example 1:

Input: [7,1,5,3,6,4]
Output: 5
Explanation: Buy on day 2 (price = 1) and sell on day 5 (price = 6), profit = 6-1 = 5.
             Not 7-1 = 6, as selling price needs to be larger than buying price.
Example 2:

Input: [7,6,4,3,1]
Output: 0
Explanation: In this case, no transaction is done, i.e. max profit = 0.
"""

def maxProfit(prices):
  min = float('inf')
  maximum = 0
  for idx in range(len(prices)):
    if prices[idx]< min:
      print("minimum",prices[idx])
      min = prices[idx]
    else:
      print("Bought: ",min,"Sold: ",prices[idx],"val: ",prices[idx]-min)
      maximum = max(prices[idx]-min, maximum)
      print("Profit: ",maximum)
  return maximum


prices = [7,1,2,8,2,6,4]
maxProfit(prices)
# Out:
# minimum 7
# minimum 1
# Bought:  1 Sold:  2 val:  1
# Profit:  1
# Bought:  1 Sold:  8 val:  7
# Profit:  7
# Bought:  1 Sold:  2 val:  1
# Profit:  7
# Bought:  1 Sold:  6 val:  5
# Profit:  7
# Bought:  1 Sold:  4 val:  3
# Profit:  7
# 7

# %%
def maxProfit(prices):
  min = float('inf')
  profit = []
  for idx in range(len(prices)):
    if prices[idx]<min:
      min = prices[idx]
      print("Got minimum value", min)
    else:
      if prices[idx] > min:
        print("Bought: ",min,"Sold: ",prices[idx],"val: ",prices[idx]-min)
        profit.append(prices[idx]-min)
        min = float('inf')
        print(profit)





prices = [7,1,2,8,2,6,4]
maxProfit(prices)
# Out:
# Got minimum value 7
# Got minimum value 1
# Bought:  1 Sold:  2 val:  1
# [1]
# Got minimum value 8
# Got minimum value 2
# Bought:  2 Sold:  6 val:  4
# [1, 4]
# Got minimum value 4

# %%
min(float('inf'),5)
# Out:
# 5

# %%
"""
198. House Robber
You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed, 
the only constraint stopping you from robbing each of them is that adjacent houses have security system connected and 
it will automatically contact the police if two adjacent houses were broken into on the same night.

Given a list of non-negative integers representing the amount of money of each house, 
determine the maximum amount of money you can rob tonight without alerting the police.

 

Example 1:

Input: nums = [1,2,3,1]
Output: 4
Explanation: Rob house 1 (money = 1) and then rob house 3 (money = 3).
             Total amount you can rob = 1 + 3 = 4.
Example 2:

Input: nums = [2,7,9,3,1]
Output: 12
Explanation: Rob house 1 (money = 2), rob house 3 (money = 9) and rob house 5 (money = 1).
             Total amount you can rob = 2 + 9 + 1 = 12.
 

Constraints:

0 <= nums.length <= 100
0 <= nums[i] <= 400

"""

def rob(nums):
  prev = curr = 0
  for num in nums:
    
    temp = prev # This represents the nums[i-2]th value
    prev = curr # This represents the nums[i-1]th value
    curr = max(num + temp, prev) # Here we just plug into the formula
    print("t:",temp,"prev:",prev,"curr: ",curr)
  return curr

def rob_bottomup(nums):
  if not nums: return 0
  if len(nums) == 1 : return nums[0]
  amt = [None] * len(nums)
  amt[0] = 0
  amt[1] = nums[0]
  for idx in range(2,len(nums)):
    amt[idx] = max(nums[idx]+amt[idx-2],amt[idx-1])
  print(amt)
  return amt.pop()


nums = [2,1,1,2]
rob_bottomup(nums)
# Out:
# [0, 2, 2, 4]
# 4

# %%
len([None]*5)
# Out:
# 5

# %%
"""
You are climbing a stair case. It takes n steps to reach to the top.

Each time you can either climb 1 or 2 steps. In how many distinct ways can you climb to the top?

Example 1:

Input: 2
Output: 2
Explanation: There are two ways to climb to the top.
1. 1 step + 1 step
2. 2 steps
Example 2:

Input: 3
Output: 3
Explanation: There are three ways to climb to the top.
1. 1 step + 1 step + 1 step
2. 1 step + 2 steps
3. 2 steps + 1 step
"""
"""
def climbStairs(self, n: int) -> int:
    res = [0,1,2]
    if n < 3:
        return res[n]
    else:
        for i in range(3,n+1):
            res.append(res[-1]+res[-2])
        return res.pop()
"""
def climbStairs(n):
  if not n : return 0
  if n in range(4): return n
  res = [None]*(n+1)
  
  for idx in range(4): res[idx] = idx 
  print(res)
  for step in range(4,n+1):
    res[step] = res[step-1] + res[step-2]
  return res.pop()

n= 5 # 5 #8
print("return",climbStairs(n))
# Out:
# [0, 1, 2, 3, None, None]
# 4 [0, 1, 2, 3, None, None]
# 5 [0, 1, 2, 3, 5, None]
# return 8

# %%
"""
784. Letter Case Permutation

Given a string S, we can transform every letter individually to be lowercase or uppercase to create another string.

Return a list of all possible strings we could create. You can return the output in any order.

Example 1:

Input: S = "a1b2"
Output: ["a1b2","a1B2","A1b2","A1B2"]
Example 2:

Input: S = "3z4"
Output: ["3z4","3Z4"]
Example 3:

Input: S = "12345"
Output: ["12345"]
Example 4:

Input: S = "0"
Output: ["0"]
"""
from itertools import product
def letterCasePermutation(S):
  letters = [set([letter.lower(),letter.upper()]) for letter in S]
  print(letters)
  res = []
  combinations = product(*letters)
  for items in combinations:
    res.append("".join(items))
  return res



S = "a1B2cd"
letterCasePermutation(S)
# Out:
# [{'a', 'A'}, {'1'}, {'b', 'B'}, {'2'}, {'c', 'C'}, {'D', 'd'}]
# ['a1b2cD', 'a1b2cd', 'a1b2CD', 'a1b2Cd', 'a1B2cD', 'a1B2cd', 'a1B2CD', 'a1B2Cd', 'A1b2cD', 'A1b2cd', 'A1b2CD', 'A1b2Cd', 'A1B2cD', 'A1B2cd', 'A1B2CD', 'A1B2Cd']

# %%
letters = [set([letter.lower(),letter.upper()]) for letter in S]
letters
# Out:
# [{'A', 'a'}, {'1'}, {'B', 'b'}, {'2'}, {'C', 'c'}, {'D', 'd'}]

# %%
from itertools import product
res = []
for i in product(*letters):
  res.append("".join(i))
res
# Out:
# ['a1b2cD',
#  'a1b2cd',
#  'a1b2CD',
#  'a1b2Cd',
#  'a1B2cD',
#  'a1B2cd',
#  'a1B2CD',
#  'a1B2Cd',
#  'A1b2cD',
#  'A1b2cd',
#  'A1b2CD',
#  'A1b2Cd',
#  'A1B2cD',
#  'A1B2cd',
#  'A1B2CD',
#  'A1B2Cd']

# %%
"""
Given an array of integers where 1 ≤ a[i] ≤ n (n = size of array), some elements appear twice and others appear once.

Find all the elements of [1, n] inclusive that do not appear in this array.

Could you do it without extra space and in O(n) runtime? You may assume the returned list does not count as extra space.

Example:

Input:
[4,3,2,7,8,2,3,1]

Output:
[5,6]
"""

    def findDisappearedNumbers(self, nums: List[int]) -> List[int]:
        res = []
        table = {}
        for val in nums:
            if val not in table:
                table[val] = True
        for val in range(1,len(nums)+1):
            if val not in table:
                res.append(val)
        return res

# %%
"""Given an array containing n distinct numbers taken from 0, 1, 2, ..., n, find the one that is missing from the array.

Example 1:

Input: [3,0,1]
Output: 2
Example 2:

Input: [9,6,4,2,3,5,7,0,1]
Output: 8
Note:
Your algorithm should run in linear runtime complexity. Could you implement it using only constant extra space complexity?

"""
def missingNumber(self, nums: List[int]) -> int:
    for val in range(len(nums)+1):
        if val not in nums:
            return val
#faster solution. as only one num is missing. we can find diff
    def missingNumber(self, nums: List[int]) -> int:
        return sum(range(len(nums)+1)) - sum(nums)
# Out:
# 8

# %%
#brute force need to improve -- O(n^3)
"""
Given a string s, find the longest palindromic substring in s. You may assume that the maximum length of s is 1000.

Example 1:
span 4
len 5
start in range(2) ===> (5-4)+1

span 3
2+1

Input: "babad"
Output: "bab"
Note: "aba" is also a valid answer.
Example 2:

Input: "cbbd"
Output: "bb"

"""

def longestPalindrome(s):
  if len(s) < 2:
    return s
  span = len(s)
  length = span
  while span > 1:
    start = 0
    end = span
    while start in range((length-span)+1):
      print(s[start:end])
      if isPalindrome(s[start:end]):
        return s[start:end]
      start += 1
      end = start + span
    span -= 1
  print("No palindrome")




s = "babada"
longestPalindrome(s)
# Out:
# babada
# babad
# abada
# baba
# abad
# bada
# bab
# 'bab'

# %%
def isPalindrome(string):
  rev_str = ""
  for letter in string[::-1]:
    rev_str += letter
  if rev_str == string:
    return True
  return False
s = "bab"
isPalindrome(s)
# Out:
# True

# %%
a="12345"
a[0:5]
if (0<=0<0):
  print("yes")

# %%
"""
917. Reverse Only Letters
Easy

609

35

Add to List

Share
Given a string S, return the "reversed" string where all characters that are not a letter stay in the same place, and all letters reverse their positions.

 

Example 1:

Input: "ab-cd"
Output: "dc-ba"
Example 2:

Input: "a-bC-dEf-ghIj"
Output: "j-Ih-gfE-dCba"
Example 3:

Input: "Test1ng-Leet=code-Q!"
Output: "Qedo1ct-eeLg=ntse-T!"
"""

string = "Test1ng-Leet=code-Q!"
res = []
for letter in string:
  if letter.isalpha():
    res.append(letter) 

result = ""
for idx,letter in enumerate(string):
  if letter.isalpha():
    print(letter, idx)
    result += res.pop()
  else:
    result += letter
    
result
# Out:
# T 0
# e 1
# s 2
# t 3
# n 5
# g 6
# L 8
# e 9
# e 10
# t 11
# c 13
# o 14
# d 15
# e 16
# Q 18
# 'Qedo1ct-eeLg=ntse-T!'

# %%
"""
The string "PAYPALISHIRING" is written in a zigzag pattern on a given number of rows like this: (you may want to display this pattern in a fixed font for better legibility)

P   A   H   N
A P L S I I G
Y   I   R
And then read line by line: "PAHNAPLSIIGYIR"

Write the code that will take a string and make this conversion given a number of rows:

string convert(string s, int numRows);
Example 1:

Input: s = "PAYPALISHIRING", numRows = 3
Output: "PAHNAPLSIIGYIR"
Example 2:

Input: s = "PAYPALISHIRING", numRows = 4
Output: "PINALSIGYAHRPI"
Explanation:

P     I    N
A   L S  I G
Y A   H R
P     I
"""

a = list("ABCDEF")
r = 5
curr = 1
table = {}
for i in range(r):
  table[i+1] = ""
print(table)
while len(a)>0:
  
  val = str(a.pop(0))
  print(curr,val,table)
  table[curr] += val

  if curr == r:
    next = r-1
  elif curr == 1:
    next = 2

  if (curr - next)== -1 and curr < r:
    curr = next
    next += 1
  elif (curr - next)== 1 and curr >1:
    curr = next
    next -= 1

  
print(table)
res = ""
for idx in range(1,r+1):
  res = res + str(table[idx])
res

#PINALSIGYAHRPI 4
#PAHNAPLSIIGYIR 3
# Out:
# {1: '', 2: '', 3: '', 4: '', 5: ''}
# 1 A {1: '', 2: '', 3: '', 4: '', 5: ''}
# 2 B {1: 'A', 2: '', 3: '', 4: '', 5: ''}
# 3 C {1: 'A', 2: 'B', 3: '', 4: '', 5: ''}
# 4 D {1: 'A', 2: 'B', 3: 'C', 4: '', 5: ''}
# 5 E {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: ''}
# 4 F {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}
# {1: 'A', 2: 'B', 3: 'C', 4: 'DF', 5: 'E'}
# 'ABCDFE'

# %%
"""
Given two sorted arrays nums1 and nums2 of size m and n respectively.

Return the median of the two sorted arrays.

Follow up: The overall run time complexity should be O(log (m+n)).

 

Example 1:

Input: nums1 = [1,3], nums2 = [2]
Output: 2.00000
Explanation: merged array = [1,2,3] and median is 2.
Example 2:

Input: nums1 = [1,2], nums2 = [3,4]
Output: 2.50000
Explanation: merged array = [1,2,3,4] and median is (2 + 3) / 2 = 2.5.

"""

# get length of array. if even -- get middle pos. else get middle pos
# pick 1st elemen of array 2 and insert in array 1 (get pos to insert)
## if insert pos < middlepos. return median

from collections import deque
def merge_arrays(arr1,arr2):
  if len(arr1) == 0:
    return arr2

  while len(arr2)>0:
    num = arr2.popleft()
    arr1 = ins(arr1,num)
    print(arr1)

def ins(arr1,num,middle = (len(arr1)//2)):
  
  prev_idx = middle-1
  print(middle,num)
  if middle not in range(0,len(arr1)):
    return arr1
  elif num == arr1[middle]:
    arr1.insert(middle,num)
    return arr1
  elif prev_idx in range(0,len(arr1)) and arr1[prev_idx] <= num <= arr1[middle]:
    arr1.insert(middle,num)
    return arr1

  elif num > arr1[middle]:
    print(num,"greater than",arr1[middle])
    middle = middle+1+(len(arr1[middle+1:])//2)
    if len(arr1) == middle:
      arr1.append(num) 
      return arr1
    return ins(arr1,num,middle)
  elif num < arr1[middle]:
    print(num,"less than",arr1[middle])
    middle = (len(arr1[:middle])//2)-1
    if middle<1:
      print("inserting on zero")
      arr1.insert(0,num)
      return arr1
    return ins(arr1,num, middle)


arr1 = [1,2,3,3,4,5]
arr2 = [3,4,5,6,7]
#arr2 = deque(arr2)
arr1 = deque(arr1)

total_elements  = len(arr1)+len(arr2)
max_median = None

if total_elements % 2 ==0:
  even = True
else: 
  even = False
max_median = (total_elements // 2)+1

merge_arrays(arr2,arr1)
# Out:
# 0 1
# 1 less than 3
# inserting on zero
# [1, 3, 4, 5, 6, 7]
# 0 2
# 2 greater than 1
# 3 2
# 2 less than 5
# inserting on zero
# [2, 1, 3, 4, 5, 6, 7]
# 0 3
# 3 greater than 2
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# 1 3
# 3 greater than 1
# 4 3
# 3 less than 5
# ...

# %%
a =[x for x in range(0,3)]
a
# Out:
# [0, 1, 2]

# %%
"""
          1
      2      3
  4      5


Depth First Traversals:
(a) Inorder (Left, Root, Right) : 4 2 5 1 3
(b) Preorder (Root, Left, Right) : 1 2 4 5 3
(c) Postorder (Left, Right, Root) : 4 5 2 3 1
"""

# %%
s = "abcabcbb"

length = len(s)

start = 0

for span in reversed(range(1,length+1)):
  print(span,s[:span])
  while start < length+1-span:
    print(s[start:start+span])
    start +=1
  start = 0
# Out:
# 8 abcabcbb
# abcabcbb
# 7 abcabcb
# abcabcb
# bcabcbb
# 6 abcabc
# abcabc
# bcabcb
# cabcbb
# 5 abcab
# abcab
# bcabc
# cabcb
# abcbb
# 4 abca
# abca
# bcab
# cabc
# abcb
# bcbb
# 3 abc
# abc
# bca
# cab
# abc
# bcb
# cbb
# 2 ab
# ab
# bc
# ca
# ab
# bc
# cb
# bb
# 1 a
# a
# b
# c
# a
# b
# c
# b
# b

# %%
for span in reversed(range()):
  print(span)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
"""
You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order and each of their nodes contain a single digit. Add the two numbers and return it as a linked list.

You may assume the two numbers do not contain any leading zero, except the number 0 itself.

Example:

Input: (2 -> 4 -> 3) + (5 -> 6 -> 4)
Output: 7 -> 0 -> 8
Explanation: 342 + 465 = 807.
"""
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        current_node = l1
        parallel_node = l2
        res1 = ""
        res2 = ""
        while current_node:            
            res1 = str(current_node.val)+res1
            current_node = current_node.next

        while parallel_node:
            res2 = str(parallel_node.val)+res2
            parallel_node = parallel_node.next
        
        res = int(res1)+int(res2)
        #print( int(res1),int(res2),res)
        
        res = list(str(res))
        
        l3 = ListNode(res.pop())
        current = l3
        while current and len(res)>0:
            
            current.next = ListNode(res.pop())
            current = current.next
            
                
        return l3

# %%
res = [11,12,13,14,15,16,17,18]
print("".join(str(x) for x in res))
# Out:
# 1112131415161718

# %%
"""
matrix 8X8 to 4X4
"""
def convert_matrix(image):
  res = []
  for row in image[::2]:
    print(row[::2])
    res.append(row[::2])
  return res


image = [[11,12,13,14,15,16,17,18],
        [21,22,23,24,25,26,27,28],
        [31,32,33,34,35,36,37,38],
        [41,42,43,44,45,46,47,48],
        [51,52,53,54,55,56,57,58],
        [61,62,63,64,65,66,67,68],
        [71,72,73,74,75,76,77,78],
        [81,82,83,84,85,86,87,88]
        ]
convert_matrix(image)
# Out:
# [11, 13, 15, 17]
# [31, 33, 35, 37]
# [51, 53, 55, 57]
# [71, 73, 75, 77]
# [[11, 13, 15, 17], [31, 33, 35, 37], [51, 53, 55, 57], [71, 73, 75, 77]]

# %%
def balance_index(arr,res,index=0,sum=0):
  if index < len(arr):
   sum += arr[index]
  else:
    return "Not balanced"
  if sum == res:
    return index
  return balance_index(arr,res,index+1,sum)
  

arr = [1,2,3,1,4,6]
res = arr[-1]
balance_index(arr,res)
# Out:
# 2

# %%
"""
make the string as anagram
"""
def anagram_str(fs,ss):
  fs_copy = fs
  ss_copy = ss
  fs=list(fs)
  ss=list(ss)

  while len(fs)>0:
    char = fs.pop()
    if char in ss:
      ss.remove(char)
    else:
      ss_copy += char
  print(fs_copy,ss_copy)
  return fs_copy,ss_copy
    
def count(str):
  table={}
  for char in str:
    if char not in table:
      table[char] = 1
    else:
      table[char] = table[char] + 1
  return table

str1 = "abcdab"
str2 = "abcddef"
# make 2 as anagram of 1
str1,str2 = anagram_str(str1,str2)
# make 1 as anagram of 2
str2, str1 = anagram_str(str2,str1)
print(str1,str2)
print(count(str1))
print(count(str2))
# Out:
# abcdab abcddefba
# abcddefba abcdabfed
# abcdabfed abcddefba
# {'a': 2, 'b': 2, 'c': 1, 'd': 2, 'f': 1, 'e': 1}
# {'a': 2, 'b': 2, 'c': 1, 'd': 2, 'e': 1, 'f': 1}

# %%
"""
Given a mobile number and some conditions for a fancy number, find if the given number is fancy. A 10 digit mobile number is called fancy if it satisfies any of the following three conditions.

A single number occurs three consecutive times. Like 777.
Three consecutive digits are either in increasing or decreasing fashion. Like 456 or 987.
A single digit occurs four or more times in the number. Like 9859009976 – here the digit 9 occurs 4 times.
"""

# update hash table with index
# if len(val) == 3 return True
# while adding to hash table update prev value.
# if p-c =1 --> dec. if next val exist and val is c-1: return true
# elif p-c = -1 --> dec. if next val exist and next_val is c+1: return true

def is_fancy(num):
  map ={}
  prev_num = None
  for idx,current_num in enumerate(num):
    current_num = int(current_num)
    if current_num not in map:
      map[current_num] = [idx]
    elif current_num in map:
      map[current_num].append(idx)
      if len(map[current_num])>2:
        print(map)
        return True
    if prev_num is not None and int(prev_num)-int(current_num) == 1:
      
      if idx+1<len(num) and int(num[idx+1]) == int(current_num) -1:
        return True
    elif prev_num is not None and int(prev_num)-int(current_num) == -1:
      
      if idx+1<len(num) and int(num[idx+1]) == int(current_num) +1:
        return True

    prev_num = current_num
  print(map)
  return False




is_fancy("98090587323")
# Out:
# {9: [0, 3], 8: [1, 6], 0: [2, 4], 5: [5], 7: [7], 3: [8, 10], 2: [9]}
# False

# %%
a = {9: [0, 3], 8: [1, 6], 0: [2, 4], 5: [5], 7: [7], 3: [8, 10], 2: [9]}
a[9] = None
if 9 in a:
  print(a)
a
# Out:
# {9: None, 8: [1, 6], 0: [2, 4], 5: [5], 7: [7], 3: [8, 10], 2: [9]}
# {0: [2, 4], 2: [9], 3: [8, 10], 5: [5], 7: [7], 8: [1, 6], 9: None}

# %%
c=5
print(1) if 5<c else 2
# Out:
# 2

# %%
int(4.9)
# Out:
# 4

# %%
"""
Implement atoi which converts a string to an integer.

The function first discards as many whitespace characters as necessary until the first non-whitespace character is found. Then, starting from this character, takes an optional initial plus or minus sign followed by as many numerical digits as possible, and interprets them as a numerical value.

The string can contain additional characters after those that form the integral number, which are ignored and have no effect on the behavior of this function.

If the first sequence of non-whitespace characters in str is not a valid integral number, or if no such sequence exists because either str is empty or it contains only whitespace characters, no conversion is performed.

If no valid conversion could be performed, a zero value is returned.

Note:

Only the space character ' ' is considered as whitespace character.
Assume we are dealing with an environment which could only store integers within the 32-bit signed integer range: [−231,  231 − 1]. If the numerical value is out of the range of representable values, INT_MAX (231 − 1) or INT_MIN (−231) is returned.
Example 1:

Input: "42"
Output: 42
Example 2:

Input: "   -42"
Output: -42
Explanation: The first non-whitespace character is '-', which is the minus sign.
             Then take as many numerical digits as possible, which gets 42.
Example 3:

Input: "4193 with words"
Output: 4193
Explanation: Conversion stops at digit '3' as the next character is not a numerical digit.
Example 4:

Input: "words and 987"
Output: 0
Explanation: The first non-whitespace character is 'w', which is not a numerical 
             digit or a +/- sign. Therefore no valid conversion could be performed.
Example 5:

Input: "-91283472332"
Output: -2147483648
Explanation: The number "-91283472332" is out of the range of a 32-bit signed integer.
             Thefore INT_MIN (−231) is returned.
"""

def myAtoi(s):
  flag = False
  res = ""
  int_min = -2**31
  int_max = 2**31 
  s = s.lstrip().split()
  print(s)
  for num in s:
    try:
      num = int(Decimal(num))

    except:
      print(num)
      return 0

    if num in range(int_min,int_max):
      return num
    else:
      if str(num)[0] == "-":
        return int_min 
      else:
         return int_max







s= "3.14159" #"-91283472332 a -4193 with words"
myAtoi(s)
# Out:
# ['3.14159']
# 3.14159
# 0

# %%
from decimal import Decimal
int(Decimal("3.14159"))
# Out:
# 3

# %%
"""
Given s="abcdeabcdee", All characters occur twice except for e which occurs 3 times. 
We can delete one instance of e to have a valid string. 
"""
# read the char in string
# update the hash table  as key and occurance
#
def validate_str(s):
  table = {}
  for element in s:
    if element not in table:
      table[element] = 1
    else:
      table[element] = table[element] + 1
  print(table)
  occurance = sorted(list(table.values()))

  memory = []
  flag = False
  for counts in occurance:
    if occurance[0] != counts and occurance[0] == counts-1:
      if flag == True:
        return False
      flag = True
    elif occurance[0] == counts:
      pass
    else:
      return False
  return True



s="abcdeabcddee"
#s = "abcdeabcdede"
validate_str(s)
# Out:
# {'a': 2, 'b': 2, 'c': 2, 'd': 3, 'e': 3}
# False

# %%
"""
Given a string, determine if it is a palindrome, considering only alphanumeric characters and ignoring cases.

Note: For the purpose of this problem, we define empty string as valid palindrome.

Example 1:

Input: "A man, a plan, a canal: Panama"
Output: true
Example 2:

Input: "race a car"
Output: false
 

Constraints:

s consists only of printable ASCII characters.

"""
def isPalindrome(s):
  org_str = []
  rev_str = []
  for val in s:
    if val.isalnum():
      org_str.append(val.lower())
      rev_str.insert(0,val.lower())
  print(org_str)
  print(rev_str)
  if org_str == rev_str:
    return True
  return False
  
 

isPalindrome("A man, a plan, a canal: Panam")
# Out:
# ['a', 'm', 'a', 'n', 'a', 'p', 'l', 'a', 'n', 'a', 'c', 'a', 'n', 'a', 'l', 'p', 'a', 'n', 'a', 'm']
# ['m', 'a', 'n', 'a', 'p', 'l', 'a', 'n', 'a', 'c', 'a', 'n', 'a', 'l', 'p', 'a', 'n', 'a', 'm', 'a']
# False

# %%
"""
Given two strings s and t , write a function to determine if t is an anagram of s.

Example 1:

Input: s = "anagram", t = "nagaram"
Output: true
Example 2:

Input: s = "rat", t = "car"
Output: false
"""
# 26 min --> misunderstood what is anagram

def isAnagram(s,t):
  if len(s) != len(t):
    return False

  array = list(s)
  for idx,val in enumerate(t):
    if val in array:
      array.remove(val)
    else:
      return False
  return True



isAnagram("anagram","nagaram")
# Out:
# True

# %%
a = list("anagram")
a.remove("n")
print(a)
# Out:
# ['a', 'a', 'g', 'r', 'a', 'm']

# %%
"""
Given a string, find the first non-repeating character in it and return its index. If it doesn't exist, return -1.

Examples:

s = "leetcode"
return 0.

s = "loveleetcode"
return 2.
 

Note: You may assume the string contains only lowercase English letters.
"""
#15 min
# update hash with element--> index, repeating as False
# if repeating update as True
def firstUniqChar(s):
  if len(s) == 0:
    return -1
  hash = {}
  for idx, val in enumerate(s):
    if val in hash:
      hash[val][1] = True
    else:
      hash[val] = [idx,False]
  print(hash)
  # returning uniqur char
  for val in s:
    if hash[val][1] == False:
      return hash[val][0]
  return -1
  


firstUniqChar("")
# Out:
# -1

# %%
#Given a sorted array nums, remove the duplicates in-place 
#such that each element appear only once and return the new length.
#Do not allocate extra space for another array, 
#you must do this by modifying the input array in-place with O(1) extra memory.

def removeDuplicates(nums,count = 0):
    if len(nums) == 0:
        return 0
    
    prev_val = nums[0]
    for current_val in nums[1:]:
        if current_val == prev_val:
            nums.remove(current_val)
            count +=1
        prev_val = current_val
    return len(nums),count
            
removeDuplicates([1, 2, 3, 3, 4])

# %%
"""
Say you have an array prices for which the ith element is the price of a given stock on day i.

Design an algorithm to find the maximum profit. You may complete as many transactions as you like (i.e., buy one and sell one share of the stock multiple times).

Note: You may not engage in multiple transactions at the same time (i.e., you must sell the stock before you buy again).

Example 1:

Input: [7,1,5,3,6,4]
Output: 7
Explanation: Buy on day 2 (price = 1) and sell on day 3 (price = 5), profit = 5-1 = 4.
             Then buy on day 4 (price = 3) and sell on day 5 (price = 6), profit = 6-3 = 3.
Example 2:

Input: [1,2,3,4,5]
Output: 4
Explanation: Buy on day 1 (price = 1) and sell on day 5 (price = 5), profit = 5-1 = 4.
             Note that you cannot buy on day 1, buy on day 2 and sell them later, as you are
             engaging multiple transactions at the same time. You must sell before buying again.
"""

#5.42PM -- 12:00AM

def maxProfit(prices):
    #[7,1,5,3,6,4]
    # gain = get diff of sub sequent values
    # if gain is large --> sell, if gain is low buy
    
    # first buy when val decreases. 7 < 1 so buy on day 2( buy val = 1)
    # if val inc and next val is inc --> sell. profit = 5-1 = 4
    # if val dec buy again . buy = 3


    # get t, t+1,t+2
    # if length <= 2 ---> when l = 1 return 0; when l=2 and inc return profit
    # else 
    # buy --> t < t+1; set stock = val 
    # sell --> if t+1 and t<t+1 and bought
    # dont sell --> if t+2<l-1 and t<t+1<t+2 
    length = len(prices)
    if length == 1:
      return 0
    elif length == 2 and prices[1]>prices[0]:
      return prices[1]-prices[0]
    else:
      stock = None
      profit = 0
      for idx in range(length):
        #intializing 3 days stock
        t = prices[idx]
        if idx+1 <len(prices):
          t1 = prices[idx+1]
        else:
          t1 = None
        print("idx",idx,":",t,t1,stock)

        #buy
        if stock is None and t1 and t<t1:
          stock = t
          print("bought",stock)

        #sell
        elif ((stock or stock == 0)  and stock<t):
          if t1 and stock<t<t1:
            pass
          else:
            profit += (t - stock)
            print("Sold",t)
            stock =None
      return profit


print(maxProfit([7,1,5,3,6,4]))
print(maxProfit([1,2,3,4,5]))
print(maxProfit([7,6,4,3,1]))
print(maxProfit([1,4,2]))
print(maxProfit([2,1,2,0,1]))

# %%
"""
Given an array, rotate the array to the right by k steps, where k is non-negative.

Follow up:

Try to come up as many solutions as you can, there are at least 3 different ways to solve this problem.
Could you do it in-place with O(1) extra space?
 

Example 1:

Input: nums = [1,2,3,4,5,6,7], k = 3
Output: [5,6,7,1,2,3,4]
Explanation:
rotate 1 steps to the right: [7,1,2,3,4,5,6]
rotate 2 steps to the right: [6,7,1,2,3,4,5]
rotate 3 steps to the right: [5,6,7,1,2,3,4]
"""
1200 -- 12:08
def rotate(nums, k):
  for _ in range(k):
    nums.insert(0,nums.pop())
  return nums


rotate([1,2,3,4,5,6,7],3)

# %%
"""
Given an array of integers, find if the array contains any duplicates.

Your function should return true if any value appears at least twice in the array, and it should return false if every element is distinct.

Example 1:

Input: [1,2,3,1]
Output: true
Example 2:

Input: [1,2,3,4]
Output: false
"""
12:10 -- 12:20
def containsDuplicate(nums):
  memory = {}
  for element in nums:
    if element not in memory:
      memory[element] = True
    else:
      return True


containsDuplicate([1,2,3,1])

# %%
a = {4: True}
print(a.pop(4))
a

# %%
"""
Given a non-empty array of integers, every element appears twice except for one. Find that single one.

Note:

Your algorithm should have a linear runtime complexity. Could you implement it without using extra memory?

Example 1:

Input: [2,2,1]
Output: 1
Example 2:

Input: [4,1,2,1,2]
Output: 4
"""
# 15 min
def singleNumber(nums):
  memory = {}
  for val in nums:
    if val in memory:
      memory.pop(val)
    else:
      memory[val] = True
  print(memory)
  return list(memory.keys()).pop()


singleNumber([2,2,1])

# %%
"""
Given a 32-bit signed integer, reverse digits of an integer.

Example 1:

Input: 123
Output: 321
Example 2:

Input: -123
Output: -321
Example 3:

Input: 120
Output: 21

Note:
Assume we are dealing with an environment which could only store 
integers within the 32-bit signed integer range: [−231,  231 − 1]. 
For the purpose of this problem, assume that your function 
returns 0 when the reversed integer overflows.
"""
def reverse(x):

  num = list(str(x))
  print(num)
  int_low = -2**31
  int_high = (2**31)-1
  if num[0] == "-":
    res = ""
    for a in num[:0:-1]:
      res += a
    res = int(-int(res))
     
  else:
    res = ""
    for a in num[::-1]:
      res += a

    res = int(res)
  if int_low<res< int_high:
    return (res)
  else:
    return 0


reverse(int(-123))
# Out:
# ['-', '1', '2', '3']
# -321

# %%
(2**31)-1
# Out:
# 2147483647

# %%
"""
Write a function that reverses a string. The input string is given as an array of characters char[].

Do not allocate extra space for another array, you must do this by modifying the input array in-place with O(1) extra memory.

You may assume all the characters consist of printable ascii characters.

 

Example 1:

Input: ["h","e","l","l","o"]
Output: ["o","l","l","e","h"]
"""

def reverseString(s):
  for idx in range(len(s)):
    s.insert(idx,s.pop())
  return s
                  


reverseString(["h","e","l","l","o"])
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %%
#6:42
"""
Given two arrays, write a function to compute their intersection.

Example 1:

Input: nums1 = [1,2,2,1], nums2 = [2,2]
Output: [2,2]
Example 2:

Input: nums1 = [4,9,5], nums2 = [9,4,9,8,4]
Output: [4,9]
Note:

Each element in the result should appear as many times as it shows in both arrays.
The result can be in any order.
"""

# set lowest length  to mem and other to comp
# create dic for mem
# while loop comp index -- condition less than comp length
# if comp[idx] in mem
# def fun is intersect(comp idx,mem index)
# start = idx , end index = s +1
# while endidx   < lenth of mem index
# if mem[s:s+1] = comp[]
def intersect(mem, comp):

  l_mem,l_comp = len(mem),len(comp)

  memory = {}
  for idx,val in enumerate(mem):
    if memory.get(val):
      memory[val].append(idx)
    else:
      memory[val] = [idx]
  
  print(memory)
  # loop ind of comp
  # if 9 in mem --> sidx = idx; lastidx = idx+1
  # while loop until mem[:] == comp[:]
  result =[]
  idx = 0

  print(result)

intersect([4,9,5],[9,4,9,8,4])
# Out:
# {4: [0], 9: [1], 5: [2]}
# [9, 4, 9, 4]

# %%
"""
Given a non-empty array of digits representing a non-negative integer, increment one to the integer.

The digits are stored such that the most significant digit is at the head of the list, and each element in the array contains a single digit.

You may assume the integer does not contain any leading zero, except the number 0 itself.

Example 1:

Input: [1,2,3]
Output: [1,2,4]
Explanation: The array represents the integer 123.
Example 2:

Input: [4,3,2,1]
Output: [4,3,2,2]
Explanation: The array represents the integer 4321.
"""

a = [9, 4, 9, 4]
res = ""
for num in a:
  res += str(num)
list(str(int(res)+1))
# Out:
# ['9', '4', '9', '5']

# %%
"""
Given an array nums, write a function to move all 0's to the end of it while maintaining the relative order of the non-zero elements.

Example:

Input: [0,1,0,3,12]
Output: [1,3,12,0,0]
Note:

You must do this in-place without making a copy of the array.
Minimize the total number of operations.
"""

nums = [1,3,0,12,0]
nums.sort(key = bool, reverse=True)
nums
# Out:
# [1, 3, 12, 0, 0]

# %%
"""
Given an array of integers, return indices of the two numbers such that they add up to a specific target.

You may assume that each input would have exactly one solution, and you may not use the same element twice.

Example:

Given nums = [2, 7, 11, 15], target = 9,

Because nums[0] + nums[1] = 2 + 7 = 9,
return [0, 1].
"""
# get element less than 9 ---> Update each element with index in form of array
# get combination of all two elements
# if sum is target 
# return indedex

from itertools import combinations
def twoSum(nums,target):
  temp = []
  for idx,val in enumerate(nums):
     temp.append([idx,val])
     
  print(temp)
  comb = combinations(temp,2)
  for i in comb:
    if(i[0][1]+i[1][1] == target):
    
      return ([i[0][0],i[1][0]])


twoSum([-3,4,3,90], 0)
# Out:
# [[0, -3], [1, 4], [2, 3], [3, 90]]
# [0, 2]

# %%
b = {0: 3, 1: 3,}
b.popitem()
# Out:
# (1, 3)

# %%
def twoSum(nums,target):
  map = {}
  for idx,val in enumerate(nums):
    diff = target-val
    if diff in map:
      return [map[diff],idx]
    map[val] = idx
  print(map)
 


twoSum([2,7,11,15], 9)
# Out:
# [0, 1]

# %%
def twoSum(nums,target):
  prevMap = {} # val : index

  for i, n in enumerate(nums):
      diff = target - n
      if diff in prevMap:
          return [prevMap[diff], i]
      prevMap[n] = i
  return
twoSum([2,7,11,15], 9)
# Out:
# [0, 1]

# %%
class node:
  def __init__(self,value):
    self.data = value
    self.left = None
    self.right = None
class bst:
  def __init__(self):
    self.root = None

  def insert(self,val):
    current_node = self.root
    new_node = node(val)
    if current_node is None:
      self.root = new_node
      print("adding root",val)
    else:
      while current_node:
      
        if current_node.data > val:
          if current_node.left is None:
            current_node.left = new_node
            print("inserting left",current_node.data, val)
            return
          else:
            current_node = current_node.left
        elif current_node.data <= val:
          if current_node.right is None:
            current_node.right = new_node
            print("inserting right",current_node.data, val)
            return
          else:
            current_node = current_node.right


if __name__ == '__main__':
  b = bst()
  b.insert(5)
  b.insert(2)
  b.insert(6)
  b.insert(5)
  b.insert(7)
  b.insert(6)
  b.insert(8)
  b.insert(1)
  """
  root: 5
inserting 2 to left of 5
inserting 6 to right of 5
inserting 5 to left of 6
inserting 7 to right of 6
inserting 6 to left of 7
inserting 8 to right of 7
inserting 1 to left of 2
""
# Out:
# adding root 5
# inserting left 5 2
# inserting right 5 6
# inserting left 6 5
# inserting right 6 7
# inserting left 7 6
# inserting right 7 8
# inserting left 2 1
